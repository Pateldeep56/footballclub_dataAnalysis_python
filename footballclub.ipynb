# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/players_20.csv")

# %%
df
# Out:
#       sofifa_id                                         player_url  \
# 0        158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2        190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3        200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4        183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...         ...                                                ...
# 2014     193290  https://sofifa.com/player/193290/martin-braith...
# 2015     193311  https://sofifa.com/player/193311/philipp-bargf...
# 2016     193338  https://sofifa.com/player/193338/mattia-destro...
# 2017     193425  https://sofifa.com/player/193425/hanno-behrens...
# 2018     193683  https://sofifa.com/player/193683/xavier-chaval...
#
#              short_name                            long_name  age         dob  \
# 0              L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1     Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2             Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3              J. Oblak                            Jan Oblak   26  1993-01-07
# 4             E. Hazard                          Eden Hazard   28  1991-01-07
# ...                 ...                                  ...  ...         ...
# 2014     M. Braithwaite                   Martin Braithwaite   28  1991-06-05
# 2015       P. Bargfrede                    Philipp Bargfrede   30  1989-03-03
# 2016          M. Destro                        Mattia Destro   28  1991-03-20
# 2017         H. Behrens                        Hanno Behrens   29  1990-03-26
# 2018      X. Chavalerin                    Xavier Chavalerin   28  1991-03-07
#
#       height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0           170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1           187         83    Portugal             Juventus  ...  65+3  61+3
# 2           175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3           188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4           175         74     Belgium          Real Madrid  ...  66+3  63+3
# ...         ...        ...         ...                  ...  ...   ...   ...
# 2014        177         73     Denmark           CD Leganés  ...  56+2  55+2
# 2015        174         71     Germany     SV Werder Bremen  ...  71+2  74+2
# 2016        182         80       Italy              Bologna  ...  48+2  46+2
# 2017        188         82     Germany       1. FC Nürnberg  ...  72+2  75+2
# 2018        179         69      France       Stade de Reims  ...   NaN   NaN
#
#        cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0     66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1     61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2     61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 2014  55+2  55+2  56+2  53+2  49+2  49+2  49+2  53+2
# 2015  74+2  74+2  71+2  71+2  73+2  73+2  73+2  71+2
# 2016  46+2  46+2  48+2  46+2  44+2  44+2  44+2  46+2
# 2017  75+2  75+2  72+2  73+2  76+2  76+2  76+2  73+2
# 2018   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2019 rows x 104 columns]

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
for col in df.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
df.shape
# Out:
# (2019, 104)

# %%
df['nationality'].value_counts()
# Out:
# Spain                   229
# Brazil                  170
# France                  167
# Argentina               149
# Germany                 128
#                        ...
# Tanzania                  1
# Dominican Republic        1
# Armenia                   1
# Central African Rep.      1
# Cuba                      1
# Name: nationality, Length: 97, dtype: int64

# %%
df['nationality'].value_counts()[0:5]
# Out:
# Spain        229
# Brazil       170
# France       167
# Argentina    149
# Germany      128
# Name: nationality, dtype: int64

# %%
df['nationality'].value_counts().keys()
# Out:
# Index(['Spain', 'Brazil', 'France', 'Argentina', 'Germany', 'England', 'Italy',
#        'Portugal', 'Netherlands', 'Uruguay', 'Belgium', 'Colombia', 'Mexico',
#        'Turkey', 'Croatia', 'Serbia', 'Switzerland', 'Denmark', 'Ivory Coast',
#        'Morocco', 'Senegal', 'Austria', 'Chile', 'Russia', 'Greece', 'Sweden',
#        'Czech Republic', 'Scotland', 'Poland', 'Ukraine', 'Norway', 'Nigeria',
#        'Japan', 'Algeria', 'Paraguay', 'Ghana', 'United States', 'Slovakia',
#        'Bosnia Herzegovina', 'Romania', 'Ecuador', 'Wales', 'Slovenia',
#        'Cameroon', 'Republic of Ireland', 'Mali', 'Cape Verde', 'Hungary',
#        'Venezuela', 'DR Congo', 'Egypt', 'Peru', 'Costa Rica', 'Montenegro',
#        'Tunisia', 'Korea Republic', 'Guinea', 'Australia', 'Jamaica',
#        'Finland', 'Togo', 'Gabon', 'Kosovo', 'Northern Ireland', 'Iceland',
#        'Albania', 'Israel', 'Angola', 'Syria', 'South Africa', 'Iran',
#        'New Zealand', 'China PR', 'FYR Macedonia', 'Moldova', 'Philippines',
#        'Benin', 'Cyprus', 'Madagascar', 'Uzbekistan', 'Guinea Bissau',
#        'Honduras', 'Mozambique', 'Bulgaria', 'Burkina Faso', 'Estonia',
#        'Canada', 'Georgia', 'Zimbabwe', 'Equatorial Guinea', 'Gambia', 'Kenya',
#        'Tanzania', 'Dominican Republic', 'Armenia', 'Central African Rep.',
#        'Cuba'],
#       dtype='object')

# %%
plt.bar(list(df['nationality'].value_counts()[0:5].keys()),list(df['nationality'].value_counts()[0:5]))
plt.show()

# %%
player_salary = df[['short_name','wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary= player_salary.sort_values(by=['wage_eur'], ascending = False)
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 22       A. Griezmann    370000
# 5        K. De Bruyne    370000

# %%
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color =["blue","red","green","yellow"])
plt.show()

# %%
df['nationality']=='Germany'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2014    False
# 2015     True
# 2016    False
# 2017     True
# 2018    False
# Name: nationality, Length: 2019, dtype: bool

# %%
Germany=df[df['nationality']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# 31         92     Germany  FC Bayern München  ...   NaN   NaN   NaN   NaN
# 36         76     Germany        Real Madrid  ...  75+3  79+3  79+3  79+3
# 37         71     Germany  Borussia Dortmund  ...  69+3  65+3  65+3  65+3
# 49         94     Germany  Borussia Dortmund  ...  77+3  83+3  83+3  83+3
#
#      rwb    lb   lcb    cb   rcb    rb
# 6    NaN   NaN   NaN   NaN   NaN   NaN
# 31   NaN   NaN   NaN   NaN   NaN   NaN
# 36  75+3  72+3  69+3  69+3  69+3  72+3
# 37  69+3  64+3  55+3  55+3  55+3  64+3
# 49  77+3  78+3  84+3  84+3  84+3  78+3
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 165      213331  https://sofifa.com/player/213331/jonathan-tah/...
# 77       212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#          short_name        long_name  age         dob  height_cm  weight_kg  \
# 1389  L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 1217       M. Esser    Michael Esser   31  1987-11-22        198         97
# 518     R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 165          J. Tah     Jonathan Tah   23  1996-02-11        195         97
# 77          N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#      nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# 1389     Germany                  PSV  ...   NaN   NaN   NaN   NaN   NaN
# 1217     Germany          Hannover 96  ...   NaN   NaN   NaN   NaN   NaN
# 518      Germany         Norwich City  ...   NaN   NaN   NaN   NaN   NaN
# 165      Germany  Bayer 04 Leverkusen  ...  70+2  76+2  76+2  76+2  70+2
# 77       Germany    FC Bayern München  ...  71+2  77+2  77+2  77+2  71+2
#
#         lb   lcb    cb   rcb    rb
# 1389   NaN   NaN   NaN   NaN   NaN
# 1217   NaN   NaN   NaN   NaN   NaN
# 518    NaN   NaN   NaN   NaN   NaN
# 165   73+2  81+2  81+2  81+2  73+2
# 77    75+2  83+2  83+2  83+2  75+2
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 77       212190  https://sofifa.com/player/212190/niklas-sule/2...
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 165      213331  https://sofifa.com/player/213331/jonathan-tah/...
#
#          short_name        long_name  age         dob  height_cm  weight_kg  \
# 1389  L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518     R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 77          N. Süle      Niklas Süle   23  1995-09-03        195         97
# 1217       M. Esser    Michael Esser   31  1987-11-22        198         97
# 165          J. Tah     Jonathan Tah   23  1996-02-11        195         97
#
#      nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# 1389     Germany                  PSV  ...   NaN   NaN   NaN   NaN   NaN
# 518      Germany         Norwich City  ...   NaN   NaN   NaN   NaN   NaN
# 77       Germany    FC Bayern München  ...  71+2  77+2  77+2  77+2  71+2
# 1217     Germany          Hannover 96  ...   NaN   NaN   NaN   NaN   NaN
# 165      Germany  Bayer 04 Leverkusen  ...  70+2  76+2  76+2  76+2  70+2
#
#         lb   lcb    cb   rcb    rb
# 1389   NaN   NaN   NaN   NaN   NaN
# 518    NaN   NaN   NaN   NaN   NaN
# 77    75+2  83+2  83+2  83+2  75+2
# 1217   NaN   NaN   NaN   NaN   NaN
# 165   73+2  81+2  81+2  81+2  73+2
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 37         M. Reus             Marco Reus   30  1989-05-31        180
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 36          76     Germany        Real Madrid  ...  75+3  79+3  79+3  79+3
# 6           85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# 55          75     Germany    Manchester City  ...  65+2  59+2  59+2  59+2
# 146         80     Germany    Manchester City  ...  76+3  79+3  79+3  79+3
# 37          71     Germany  Borussia Dortmund  ...  69+3  65+3  65+3  65+3
#
#       rwb    lb   lcb    cb   rcb    rb
# 36   75+3  72+3  69+3  69+3  69+3  72+3
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 55   65+2  61+2  52+2  52+2  52+2  61+2
# 146  76+3  74+3  72+3  72+3  72+3  74+3
# 37   69+3  64+3  55+3  55+3  55+3  64+3
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending = False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 37         M. Reus    170000

# %%
player_shooting = df[['short_name','shooting']]
player_shooting.head()
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0

# %%
player_defending = df[['short_name','defending','nationality','club']]
player_defending.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 16  G. Chiellini       90.0        Italy           Juventus
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 49    M. Hummels       89.0      Germany  Borussia Dortmund
# 35      D. Godín       89.0      Uruguay              Inter

# %%
real_madrid=df[df['club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4      Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3
# 8      Croatia  Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3
# 36     Germany  Real Madrid  ...  75+3  79+3  79+3  79+3  75+3  72+3  69+3
# 18       Spain  Real Madrid  ...  80+3  84+3  84+3  84+3  80+3  82+3  87+3
# 46      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3  58+3  54+3
#
#       cb   rcb    rb
# 4   49+3  49+3  61+3
# 8   72+3  72+3  79+3
# 36  69+3  69+3  72+3
# 18  87+3  87+3  82+3
# 46  54+3  54+3  58+3
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 100         82       Wales  Real Madrid  ...  72+3  69+3  69+3  69+3  72+3
# 106         75    Colombia  Real Madrid  ...  67+3  67+3  67+3  67+3  67+3
# 4           74     Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3
# 161         85      Serbia  Real Madrid  ...  55+2  53+2  53+2  53+2  55+2
# 46          81      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3
#
#        lb   lcb    cb   rcb    rb
# 100  70+3  66+3  66+3  66+3  70+3
# 106  62+3  57+3  57+3  57+3  62+3
# 4    61+3  49+3  49+3  49+3  61+3
# 161  51+2  47+2  47+2  47+2  51+2
# 46   58+3  54+3  54+3  54+3  58+3
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 277     200724  https://sofifa.com/player/200724/jose-ignacio-...
#
#           short_name                          long_name  age         dob  \
# 18      Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42          Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76         R. Varane                     Raphaël Varane   26  1993-04-25
# 94          Carvajal              Daniel Carvajal Ramos   27  1992-01-11
# 277  Nacho Fernández    José Ignacio Fernández Iglesias   29  1990-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 18         184         82       Spain  Real Madrid  ...  80+3  84+3  84+3
# 42         185         84      Brazil  Real Madrid  ...  78+3  84+3  84+3
# 76         191         81      France  Real Madrid  ...  74+3  79+3  79+3
# 94         173         73       Spain  Real Madrid  ...  83+3  82+3  82+3
# 277        180         76       Spain  Real Madrid  ...  77+2  76+2  76+2
#
#       rdm   rwb    lb   lcb    cb   rcb    rb
# 18   84+3  80+3  82+3  87+3  87+3  87+3  82+3
# 42   84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 76   79+3  74+3  77+3  83+3  83+3  83+3  77+3
# 94   82+3  83+3  83+3  80+3  80+3  80+3  83+3
# 277  76+2  77+2  78+2  80+2  80+2  80+2  78+2
#
# [5 rows x 104 columns]
# Warning: Total number of columns (104) exceeds max_columns (20) limiting to first (20) columns.
